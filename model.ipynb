# %%
import pandas as pd
import numpy as np
import joblib
from sklearn import set_config, get_config
from sklearn.ensemble import StackingRegressor
from sklearn.impute import SimpleImputer
from sklearn.model_selection import cross_validate
from sklearn.pipeline import Pipeline

from model.core import MODEL_DIR, load_Xy
from model.elasticnet import similar_transformer
from model.xgb import categorical_features

# %%
set_config(transform_output='pandas')

# %%
X, y = load_Xy()
xgb_model = joblib.load(MODEL_DIR / './models/xgb_model.joblib')
#xgb_model2 = joblib.load(MODEL_DIR / './models/xgb_model2.joblib')
#xgb_model3 = joblib.load(MODEL_DIR / './models/xgb_model3.joblib')
svr_model = joblib.load(MODEL_DIR / './models/linear_svr_model.joblib')
rbf_model = joblib.load(MODEL_DIR / './models/rbf_model.joblib')
ridge_model = joblib.load(MODEL_DIR / './models/ridge_model.joblib')
elasticnet_model = joblib.load(MODEL_DIR / './models/elasticnet_model.joblib')

# %%
# Out:
# ColumnTransformer(sparse_threshold=0,
#                   transformers=[('categorical',
#                                  Pipeline(steps=[('impute',
#                                                   SimpleImputer(fill_value='MISSING_VALUE',
#                                                                 strategy='constant')),
#                                                  ('encode',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False))]),
#                                  ['developer_metacritic']),
#                                 ('numerical',
#                                  Pipeline(steps=[('impute', SimpleImputer()),
#                                                  ('scale', StandardScaler())]),
#                                  ['percentRec...
#                                  Pipeline(steps=[('encode', SummarizeSimilar()),
#                                                  ('impute', SimpleImputer()),
#                                                  ('scale', StandardScaler())]),
#                                  ['id_igdb', 'similar_games_igdb', 'Finished',
#                                   'glicko']),
#                                 ('genre_mc_clean', PandasCountVectorizer(),
#                                  'genre_mc_clean'),
#                                 ('genres_igdb', PandasCountVectorizer(),
#                                  'genres_igdb'),
#                                 ('themes_igdb', PandasCountVectorizer(),
#                                  'themes_igdb'),
#                                 ('Genres', PandasDictVectorizer(sparse=False),
#                                  'Genres')])

# %%
model = StackingRegressor(
    estimators=[
        ('ridge', ridge_model),
        ('elasticnet', elasticnet_model),
        ('xgb', xgb_model),
        #('xgb2', xgb_model2),
        #('xgb3', xgb_model3),
        ('svr', svr_model),
        ('rbf', rbf_model),
    ],
    cv=5,
    verbose=1,
)
ridge_cv = cross_validate(ridge_model, X, y, scoring='neg_mean_squared_error', cv=5)
elasticnet_cv = cross_validate(elasticnet_model, X, y, scoring='neg_mean_squared_error', cv=5)
xgb_cv = cross_validate(xgb_model, X, y, scoring='neg_mean_squared_error', cv=5)
svr_cv = cross_validate(svr_model, X, y, scoring='neg_mean_squared_error', cv=5)
rbf_cv = cross_validate(rbf_model, X, y, scoring='neg_mean_squared_error', cv=5)
stack_cv = cross_validate(model, X, y, scoring='neg_mean_squared_error', cv=5)
# Out:
# C:\Users\derek\DataspellProjects\derks-backlog\.venv\Lib\site-packages\xgboost\core.py:729: UserWarning: [18:09:08] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\common\error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   return func(**kwargs)
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   25.8s finished
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.1s finished
# C:\Users\derek\DataspellProjects\derks-backlog\.venv\Lib\site-packages\sklearn\utils\validation.py:2742: UserWarning: X has feature names, but RidgeCV was fitted without feature names
#   warnings.warn(
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   25.7s finished
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.1s finished
# C:\Users\derek\DataspellProjects\derks-backlog\.venv\Lib\site-packages\sklearn\utils\validation.py:2742: UserWarning: X has feature names, but RidgeCV was fitted without feature names
#   warnings.warn(
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   25.8s finished
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.1s finished
# C:\Users\derek\DataspellProjects\derks-backlog\.venv\Lib\site-packages\sklearn\utils\validation.py:2742: UserWarning: X has feature names, but RidgeCV was fitted without feature names
#   warnings.warn(
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   25.5s finished
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.1s finished
# C:\Users\derek\DataspellProjects\derks-backlog\.venv\Lib\site-packages\sklearn\utils\validation.py:2742: UserWarning: X has feature names, but RidgeCV was fitted without feature names
#   warnings.warn(
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   25.5s finished
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.1s finished
# C:\Users\derek\DataspellProjects\derks-backlog\.venv\Lib\site-packages\sklearn\utils\validation.py:2742: UserWarning: X has feature names, but RidgeCV was fitted without feature names
#   warnings.warn(

# %%
ridge_cv
# Out:
# {'fit_time': array([0.04700041, 0.05851293, 0.0470047 , 0.04668069, 0.04856992]),
#  'score_time': array([0.0130024 , 0.01299739, 0.01351047, 0.01400113, 0.01399922]),
#  'test_score': array([-25567.28133596, -34916.24473728, -25462.45550807, -42515.00537346,
#         -40826.99614764])}

# %%
elasticnet_cv
# Out:
# {'fit_time': array([0.03700018, 0.03752112, 0.03899884, 0.03851104, 0.03699756]),
#  'score_time': array([0.0130024 , 0.01500106, 0.01299763, 0.01299977, 0.01300645]),
#  'test_score': array([-24989.48268867, -35005.38675827, -32409.13641316, -39937.76270537,
#         -41830.3930961 ])}

# %%
X.fillna(0.).values
# Out:
# array([[0.0, 0.0, 0.0, ...,
#         '[358, 843, 1068, 1078, 1079, 1103, 1185, 2180, 3349, 9061]',
#         1.0, 968.9387124290148],
#        ['2D Platformer', 'M2', 0.0, ...,
#         '[43367, 51485, 55190, 56033, 57187, 81183, 87728, 110503, 117311, 200989]',
#         1.0, 1432.7693318282927],
#        ['Metroidvania', 'Nintendo', 0.0, ...,
#         '[1025, 1026, 1070, 1101, 1741, 3222, 18182, 26226, 26820, 103329]',
#         1.0, 1803.6924564563933],
#        ...,
#        [0.0, 0.0, 96.94656488549616, ...,
#         '[96217, 106987, 22387, 115653, 81249, 103303, 115280, 55038, 113360, 27092]',
#         1.0, 1771.662373388982],
#        ['Rhythm', 'Drool', 88.46153846153845, ...,
#         '[56033, 36198, 31194, 3222, 114455, 18869, 55173, 111130, 19301, 19150]',
#         1.0, 1333.6010630510505],
#        ['Action RPG', 'Round 8 Studio of NEOWIZ', 100.0, ...,
#         '[81249, 19164, 103303, 102584, 111130, 18225, 26574, 96217, 116530, 106987]',
#         1.0, 1606.7849028955127]], shape=(322, 40), dtype=object)

# %%
xgb_cv
# Out:
# {'fit_time': array([6.07340574, 5.90862703, 5.93781948, 5.80294514, 5.89161968]),
#  'score_time': array([0.03900242, 0.03600097, 0.03610611, 0.03699946, 0.03499985]),
#  'test_score': array([-24004.42171164, -39197.51186638, -31425.8145868 , -47013.72935369,
#         -62315.04163012])}

# %%
stack_cv
# Out:
# {'fit_time': array([32.99667525, 33.14212537, 33.04780626, 32.7185595 , 32.79580045]),
#  'score_time': array([0.09951186, 0.09849286, 0.10150719, 0.09851217, 0.10051489]),
#  'test_score': array([-22215.51419516, -32231.9103747 , -23678.90263743, -40579.18441449,
#         -38031.27550616])}

# %%
set_config(transform_output='default')

# %%
from pytabkit import Ensemble_HPO_Regressor
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from model.core import (
    PandasDictVectorizer,
    PandasCountVectorizer,
    CategoricalEncoder,
    SummarizeSimilar,
    LIST_FEATURES,
    NUMERICAL_FEATURES,
    CATEGORICAL_FEATURES,
    DICT_FEATURES,
    MODEL_DIR,
    load_Xy,
    SIMILAR_FEATURES,
)

# categorize features by preprocessing
numerical_features = NUMERICAL_FEATURES.copy()
categorical_features = CATEGORICAL_FEATURES.copy()
dict_features = DICT_FEATURES.copy()
list_features = LIST_FEATURES.copy()
similar_features = SIMILAR_FEATURES.copy()

# %%
# define preprocessors
list_transformers = []
for n in list_features:
    list_transformers.append((n, PandasCountVectorizer(input='content'), n))

dict_transformers = []
for n in dict_features:
    dict_transformers.append((n, PandasDictVectorizer(sparse=False), n))

categorical_transformer = Pipeline([
    ('encode', CategoricalEncoder(handle_unknown='use_encoded_value', unknown_value=np.nan)),
    #('impute', SimpleImputer(fill_value=-1)),
])

similar_transformer = Pipeline([
    ('summarize', SummarizeSimilar()),
    ('impute', SimpleImputer())
])

nonlist_transformers = [
    ('categorical', categorical_transformer, categorical_features),
    ('numerical', SimpleImputer(), numerical_features),
    ('similar', similar_transformer, similar_features),
]


column_transformer = ColumnTransformer(
    transformers=nonlist_transformers+list_transformers+dict_transformers,
    sparse_threshold=0
)

# %%
preprocessor = column_transformer
preprocessor.set_output(transform='pandas')
# Out:
# ColumnTransformer(sparse_threshold=0,
#                   transformers=[('categorical',
#                                  Pipeline(steps=[('encode',
#                                                   CategoricalEncoder(handle_unknown='use_encoded_value',
#                                                                      unknown_value=nan))]),
#                                  ['genre_metacritic', 'developer_metacritic']),
#                                 ('numerical', SimpleImputer(),
#                                  ['percentRecommended', 'numReviews',
#                                   'numTopCriticReviews', 'topCriticScore',
#                                   'aggregated_rating_igdb',
#                                   'aggregat...
#                                  Pipeline(steps=[('summarize',
#                                                   SummarizeSimilar()),
#                                                  ('impute', SimpleImputer())]),
#                                  ['id_igdb', 'similar_games_igdb', 'Finished',
#                                   'glicko']),
#                                 ('genre_mc_clean', PandasCountVectorizer(),
#                                  'genre_mc_clean'),
#                                 ('genres_igdb', PandasCountVectorizer(),
#                                  'genres_igdb'),
#                                 ('themes_igdb', PandasCountVectorizer(),
#                                  'themes_igdb'),
#                                 ('Genres', PandasDictVectorizer(sparse=False),
#                                  'Genres')])

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
model = Ensemble_HPO_Regressor(
    n_cv=5,
    use_full_caruana_ensembling=True,
    use_tabarena_spaces=True,
    n_hpo_steps=50,
    #val_metric_name='mse',
    device='cuda:0',
)
pipe = Pipeline([
    ('preprocess', preprocessor),
    ('model', model)
])

# %%
ptk_cv = cross_validate(pipe, X, y, scoring='neg_mean_squared_error', cv=5, params={'model__cat_col_names': ['categorical__genre_metacritic', 'categorical__developer_metacritic']}, error_score='raise')
# Out:
# self.fit_params[0]={'early_stopping_rounds': 300, 'n_estimators': 10000, 'learning_rate': np.float64(0.006259412766996183), 'feature_fraction': 0.6878428925584417, 'bagging_fraction': 0.7441573724081981, 'bagging_freq': 1, 'num_leaves': np.float64(3.0), 'min_data_in_leaf': np.float64(5.0), 'extra_trees': np.True_, 'min_data_per_group': np.float64(93.0), 'cat_l2': np.float64(0.01787306292976289), 'cat_smooth': np.float64(0.05146331293850836), 'max_cat_to_onehot': np.float64(9.0), 'lambda_l1': np.float64(0.0029349163644412707), 'lambda_l2': np.float64(0.0012074471066395999)}
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# self.fit_params[0]={'early_stopping_rounds': 300, 'n_estimators': 10000, 'learning_rate': np.float64(0.011183442040921405), 'feature_fraction': 0.9844105840958441, 'bagging_fraction': 0.7455927191168633, 'bagging_freq': 1, 'num_leaves': np.float64(48.0), 'min_data_in_leaf': np.float64(24.0), 'extra_trees': np.False_, 'min_data_per_group': np.float64(17.0), 'cat_l2': np.float64(1.3411123200717139), 'cat_smooth': np.float64(0.02903155569508162), 'max_cat_to_onehot': np.float64(43.0), 'lambda_l1': np.float64(0.0673197781032052), 'lambda_l2': np.float64(1.9759566739307728)}
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# self.fit_params[0]={'early_stopping_rounds': 300, 'n_estimators': 10000, 'learning_rate': np.float64(0.08258942937466404), 'feature_fraction': 0.5560980579076011, 'bagging_fraction': 0.7261233988844124, 'bagging_freq': 1, 'num_leaves': np.float64(198.0), 'min_data_in_leaf': np.float64(5.0), 'extra_trees': np.False_, 'min_data_per_group': np.float64(89.0), 'cat_l2': np.float64(0.18038548509686153), 'cat_smooth': np.float64(24.346326689674047), 'max_cat_to_onehot': np.float64(74.0), 'lambda_l1': np.float64(0.001096749050648279), 'lambda_l2': np.float64(0.023339703302362565)}
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# self.fit_params[0]={'early_stopping_rounds': 300, 'n_estimators': 10000, 'learning_rate': np.float64(0.02447971676840772), 'feature_fraction': 0.6176809750394093, 'bagging_fraction': 0.7758038146232753, 'bagging_freq': 1, 'num_leaves': np.float64(58.0), 'min_data_in_leaf': np.float64(19.0), 'extra_trees': np.False_, 'min_data_per_group': np.float64(4.0), 'cat_l2': np.float64(0.6615244909583101), 'cat_smooth': np.float64(0.0017837005998483123), 'max_cat_to_onehot': np.float64(26.0), 'lambda_l1': np.float64(3.648533385409274e-05), 'lambda_l2': np.float64(0.0009851729169615)}
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# self.fit_params[0]={'early_stopping_rounds': 300, 'n_estimators': 10000, 'learning_rate': np.float64(0.05844266290629866), 'feature_fraction': 0.8374741861172128, 'bagging_fraction': 0.8812126077521101, 'bagging_freq': 1, 'num_leaves': np.float64(10.0), 'min_data_in_leaf': np.float64(1.0), 'extra_trees': np.True_, 'min_data_per_group': np.float64(8.0), 'cat_l2': np.float64(0.10465216242640989), 'cat_smooth': np.float64(4.165492666306571), 'max_cat_to_onehot': np.float64(50.0), 'lambda_l1': np.float64(0.0005341303027208886), 'lambda_l2': np.float64(0.00023073201949042334)}
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# self.fit_params[0]={'early_stopping_rounds': 300, 'n_estimators': 10000, 'learning_rate': np.float64(0.06276648589619285), 'feature_fraction': 0.5509064410517006, 'bagging_fraction': 0.8767212210171789, 'bagging_freq': 1, 'num_leaves': np.float64(11.0), 'min_data_in_leaf': np.float64(1.0), 'extra_trees': np.False_, 'min_data_per_group': np.float64(92.0), 'cat_l2': np.float64(0.027332146562701574), 'cat_smooth': np.float64(0.8624417673779349), 'max_cat_to_onehot': np.float64(10.0), 'lambda_l1': np.float64(0.15984764688239622), 'lambda_l2': np.float64(0.18678135679611757)}
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# self.fit_params[0]={'early_stopping_rounds': 300, 'n_estimators': 10000, 'learning_rate': np.float64(0.03536730859732128), 'feature_fraction': 0.6057724982640623, 'bagging_fraction': 0.8883885162143558, 'bagging_freq': 1, 'num_leaves': np.float64(15.0), 'min_data_in_leaf': np.float64(19.0), 'extra_trees': np.False_, 'min_data_per_group': np.float64(21.0), 'cat_l2': np.float64(1.1321713353288876), 'cat_smooth': np.float64(89.49976832316686), 'max_cat_to_onehot': np.float64(40.0), 'lambda_l1': np.float64(0.16501258573651562), 'lambda_l2': np.float64(0.05148011096997045)}
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# self.fit_params[0]={'early_stopping_rounds': 300, 'n_estimators': 10000, 'learning_rate': np.float64(0.016327394487041617), 'feature_fraction': 0.8956739506782476, 'bagging_fraction': 0.932519354750416, 'bagging_freq': 1, 'num_leaves': np.float64(86.0), 'min_data_in_leaf': np.float64(62.0), 'extra_trees': np.False_, 'min_data_per_group': np.float64(22.0), 'cat_l2': np.float64(0.07907535576221154), 'cat_smooth': np.float64(84.45592647305432), 'max_cat_to_onehot': np.float64(30.0), 'lambda_l1': np.float64(0.20817086655767664), 'lambda_l2': np.float64(0.08808770552034628)}
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# self.fit_params[0]={'early_stopping_rounds': 300, 'n_estimators': 10000, 'learning_rate': np.float64(0.006975973059218868), 'feature_fraction': 0.8593128349852002, 'bagging_fraction': 0.9264557800759995, 'bagging_freq': 1, 'num_leaves': np.float64(2.0), 'min_data_in_leaf': np.float64(1.0), 'extra_trees': np.False_, 'min_data_per_group': np.float64(12.0), 'cat_l2': np.float64(0.15360831181034562), 'cat_smooth': np.float64(0.07038061491611759), 'max_cat_to_onehot': np.float64(50.0), 'lambda_l1': np.float64(0.0006019630767663475), 'lambda_l2': np.float64(3.209048224631372e-05)}
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# self.fit_params[0]={'early_stopping_rounds': 300, 'n_estimators': 10000, 'learning_rate': np.float64(0.05980438281797063), 'feature_fraction': 0.6691462691348458, 'bagging_fraction': 0.9509536027756809, 'bagging_freq': 1, 'num_leaves': np.float64(147.0), 'min_data_in_leaf': np.float64(8.0), 'extra_trees': np.True_, 'min_data_per_group': np.float64(97.0), 'cat_l2': np.float64(0.007435770180033182), 'cat_smooth': np.float64(0.3108095223754356), 'max_cat_to_onehot': np.float64(92.0), 'lambda_l1': np.float64(0.04200952678065939), 'lambda_l2': np.float64(0.06356930672918719)}
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# self.fit_params[0]={'early_stopping_rounds': 300, 'n_estimators': 10000, 'learning_rate': np.float64(0.05903888061344897), 'feature_fraction': 0.9747461992317116, 'bagging_fraction': 0.8538046746853472, 'bagging_freq': 1, 'num_leaves': np.float64(33.0), 'min_data_in_leaf': np.float64(27.0), 'extra_trees': np.True_, 'min_data_per_group': np.float64(16.0), 'cat_l2': np.float64(0.44537076919319063), 'cat_smooth': np.float64(60.469718296242206), 'max_cat_to_onehot': np.float64(36.0), 'lambda_l1': np.float64(0.32305984401011345), 'lambda_l2': np.float64(6.290353615978282e-05)}
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# self.fit_params[0]={'early_stopping_rounds': 300, 'n_estimators': 10000, 'learning_rate': np.float64(0.019950634706857883), 'feature_fraction': 0.9692970980195572, 'bagging_fraction': 0.982680641724906, 'bagging_freq': 1, 'num_leaves': np.float64(40.0), 'min_data_in_leaf': np.float64(7.0), 'extra_trees': np.False_, 'min_data_per_group': np.float64(30.0), 'cat_l2': np.float64(0.14843121223572772), 'cat_smooth': np.float64(0.04105550950878819), 'max_cat_to_onehot': np.float64(11.0), 'lambda_l1': np.float64(0.00028313881651542255), 'lambda_l2': np.float64(3.328793249782655e-05)}
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# self.fit_params[0]={'early_stopping_rounds': 300, 'n_estimators': 10000, 'learning_rate': np.float64(0.035815058916289326), 'feature_fraction': 0.4107795134356726, 'bagging_fraction': 0.7263678458573528, 'bagging_freq': 1, 'num_leaves': np.float64(106.0), 'min_data_in_leaf': np.float64(4.0), 'extra_trees': np.False_, 'min_data_per_group': np.float64(2.0), 'cat_l2': np.float64(0.05486826206778346), 'cat_smooth': np.float64(0.003849250029709182), 'max_cat_to_onehot': np.float64(11.0), 'lambda_l1': np.float64(8.944839505774258e-05), 'lambda_l2': np.float64(0.10945115436959962)}
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# self.fit_params[0]={'early_stopping_rounds': 300, 'n_estimators': 10000, 'learning_rate': np.float64(0.005805302432661942), 'feature_fraction': 0.4517381838831767, 'bagging_fraction': 0.9104840048921292, 'bagging_freq': 1, 'num_leaves': np.float64(7.0), 'min_data_in_leaf': np.float64(3.0), 'extra_trees': np.False_, 'min_data_per_group': np.float64(3.0), 'cat_l2': np.float64(1.295125507927186), 'cat_smooth': np.float64(10.927534425994963), 'max_cat_to_onehot': np.float64(10.0), 'lambda_l1': np.float64(0.11924450808794311), 'lambda_l2': np.float64(0.02784660803291631)}
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# self.fit_params[0]={'early_stopping_rounds': 300, 'n_estimators': 10000, 'learning_rate': np.float64(0.03599092462960644), 'feature_fraction': 0.9681247307677158, 'bagging_fraction': 0.9528939411125867, 'bagging_freq': 1, 'num_leaves': np.float64(8.0), 'min_data_in_leaf': np.float64(2.0), 'extra_trees': np.False_, 'min_data_per_group': np.float64(12.0), 'cat_l2': np.float64(0.016443455884758013), 'cat_smooth': np.float64(4.543084981978966), 'max_cat_to_onehot': np.float64(14.0), 'lambda_l1': np.float64(0.005925673314406743), 'lambda_l2': np.float64(1.0593546546736217)}
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# self.fit_params[0]={'early_stopping_rounds': 300, 'n_estimators': 10000, 'learning_rate': np.float64(0.04369861607306223), 'feature_fraction': 0.7759035295170973, 'bagging_fraction': 0.9510055973379599, 'bagging_freq': 1, 'num_leaves': np.float64(78.0), 'min_data_in_leaf': np.float64(19.0), 'extra_trees': np.False_, 'min_data_per_group': np.float64(11.0), 'cat_l2': np.float64(0.6037586961793735), 'cat_smooth': np.float64(1.078298189947501), 'max_cat_to_onehot': np.float64(62.0), 'lambda_l1': np.float64(0.00042658559453863967), 'lambda_l2': np.float64(0.016352806889688144)}
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# self.fit_params[0]={'early_stopping_rounds': 300, 'n_estimators': 10000, 'learning_rate': np.float64(0.02658516197807651), 'feature_fraction': 0.9527023879838659, 'bagging_fraction': 0.7662825662838971, 'bagging_freq': 1, 'num_leaves': np.float64(2.0), 'min_data_in_leaf': np.float64(2.0), 'extra_trees': np.True_, 'min_data_per_group': np.float64(24.0), 'cat_l2': np.float64(0.14508076328699746), 'cat_smooth': np.float64(31.066286025080863), 'max_cat_to_onehot': np.float64(54.0), 'lambda_l1': np.float64(1.0810244038105845e-05), 'lambda_l2': np.float64(0.33488775833386375)}
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# self.fit_params[0]={'early_stopping_rounds': 300, 'n_estimators': 10000, 'learning_rate': np.float64(0.019517855195247798), 'feature_fraction': 0.7979111863949888, 'bagging_fraction': 0.8566682836930946, 'bagging_freq': 1, 'num_leaves': np.float64(11.0), 'min_data_in_leaf': np.float64(1.0), 'extra_trees': np.False_, 'min_data_per_group': np.float64(8.0), 'cat_l2': np.float64(0.7704163295966372), 'cat_smooth': np.float64(0.2772612066724548), 'max_cat_to_onehot': np.float64(23.0), 'lambda_l1': np.float64(0.18167322641025918), 'lambda_l2': np.float64(0.0007295575444609035)}
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# self.fit_params[0]={'early_stopping_rounds': 300, 'n_estimators': 10000, 'learning_rate': np.float64(0.03569715939619957), 'feature_fraction': 0.4944516446903608, 'bagging_fraction': 0.9383352200134989, 'bagging_freq': 1, 'num_leaves': np.float64(196.0), 'min_data_in_leaf': np.float64(26.0), 'extra_trees': np.True_, 'min_data_per_group': np.float64(18.0), 'cat_l2': np.float64(0.5820698172918595), 'cat_smooth': np.float64(0.7326070056092366), 'max_cat_to_onehot': np.float64(12.0), 'lambda_l1': np.float64(0.027421060112548995), 'lambda_l2': np.float64(0.0033057466158151394)}
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# self.fit_params[0]={'early_stopping_rounds': 300, 'n_estimators': 10000, 'learning_rate': np.float64(0.038786373652236084), 'feature_fraction': 0.43270738005758846, 'bagging_fraction': 0.7007648405776061, 'bagging_freq': 1, 'num_leaves': np.float64(44.0), 'min_data_in_leaf': np.float64(1.0), 'extra_trees': np.True_, 'min_data_per_group': np.float64(98.0), 'cat_l2': np.float64(0.3652620131836482), 'cat_smooth': np.float64(0.0821732334044722), 'max_cat_to_onehot': np.float64(18.0), 'lambda_l1': np.float64(0.00958396559321175), 'lambda_l2': np.float64(0.7421819869096448)}
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# self.fit_params[0]={'early_stopping_rounds': 300, 'n_estimators': 10000, 'learning_rate': np.float64(0.015049060452015596), 'feature_fraction': 0.9849105746421878, 'bagging_fraction': 0.8312374872738331, 'bagging_freq': 1, 'num_leaves': np.float64(81.0), 'min_data_in_leaf': np.float64(54.0), 'extra_trees': np.True_, 'min_data_per_group': np.float64(11.0), 'cat_l2': np.float64(0.09027667137559361), 'cat_smooth': np.float64(14.172530475509198), 'max_cat_to_onehot': np.float64(15.0), 'lambda_l1': np.float64(0.0005245810021558913), 'lambda_l2': np.float64(0.006632712073039153)}
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# self.fit_params[0]={'early_stopping_rounds': 300, 'n_estimators': 10000, 'learning_rate': np.float64(0.07506107395670433), 'feature_fraction': 0.4621970322274195, 'bagging_fraction': 0.72909413291231, 'bagging_freq': 1, 'num_leaves': np.float64(78.0), 'min_data_in_leaf': np.float64(6.0), 'extra_trees': np.True_, 'min_data_per_group': np.float64(7.0), 'cat_l2': np.float64(0.0292734989285101), 'cat_smooth': np.float64(0.00962010728569006), 'max_cat_to_onehot': np.float64(54.0), 'lambda_l1': np.float64(0.0005933624825377579), 'lambda_l2': np.float64(0.00031362116569011396)}
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# self.fit_params[0]={'early_stopping_rounds': 300, 'n_estimators': 10000, 'learning_rate': np.float64(0.008537401868569093), 'feature_fraction': 0.5344656877144831, 'bagging_fraction': 0.8257828917755428, 'bagging_freq': 1, 'num_leaves': np.float64(9.0), 'min_data_in_leaf': np.float64(25.0), 'extra_trees': np.False_, 'min_data_per_group': np.float64(11.0), 'cat_l2': np.float64(0.04822403438751829), 'cat_smooth': np.float64(8.31630430859381), 'max_cat_to_onehot': np.float64(58.0), 'lambda_l1': np.float64(0.04855356920162489), 'lambda_l2': np.float64(0.00012482077195061857)}
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# self.fit_params[0]={'early_stopping_rounds': 300, 'n_estimators': 10000, 'learning_rate': np.float64(0.018334230225147206), 'feature_fraction': 0.6369579895557628, 'bagging_fraction': 0.9642475846731721, 'bagging_freq': 1, 'num_leaves': np.float64(36.0), 'min_data_in_leaf': np.float64(5.0), 'extra_trees': np.False_, 'min_data_per_group': np.float64(48.0), 'cat_l2': np.float64(0.19433478980806382), 'cat_smooth': np.float64(0.9541414319580211), 'max_cat_to_onehot': np.float64(69.0), 'lambda_l1': np.float64(0.0030835899569860614), 'lambda_l2': np.float64(3.519356120833638e-05)}
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# self.fit_params[0]={'early_stopping_rounds': 300, 'n_estimators': 10000, 'learning_rate': np.float64(0.04307140183839064), 'feature_fraction': 0.8483663618989816, 'bagging_fraction': 0.8135598106609426, 'bagging_freq': 1, 'num_leaves': np.float64(19.0), 'min_data_in_leaf': np.float64(2.0), 'extra_trees': np.False_, 'min_data_per_group': np.float64(3.0), 'cat_l2': np.float64(0.022052450901089534), 'cat_smooth': np.float64(4.392844976581513), 'max_cat_to_onehot': np.float64(13.0), 'lambda_l1': np.float64(0.00015868898275938077), 'lambda_l2': np.float64(1.4929702491750612)}
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# self.fit_params[0]={'early_stopping_rounds': 300, 'n_estimators': 10000, 'learning_rate': np.float64(0.015936502984935395), 'feature_fraction': 0.832971165933313, 'bagging_fraction': 0.7663669430017892, 'bagging_freq': 1, 'num_leaves': np.float64(5.0), 'min_data_in_leaf': np.float64(1.0), 'extra_trees': np.True_, 'min_data_per_group': np.float64(25.0), 'cat_l2': np.float64(0.1493791608670342), 'cat_smooth': np.float64(6.842179817734157), 'max_cat_to_onehot': np.float64(74.0), 'lambda_l1': np.float64(0.005566504172121972), 'lambda_l2': np.float64(0.008363712324400358)}
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# self.fit_params[0]={'early_stopping_rounds': 300, 'n_estimators': 10000, 'learning_rate': np.float64(0.027378754927531744), 'feature_fraction': 0.6838172750622432, 'bagging_fraction': 0.9724337608761504, 'bagging_freq': 1, 'num_leaves': np.float64(52.0), 'min_data_in_leaf': np.float64(2.0), 'extra_trees': np.True_, 'min_data_per_group': np.float64(5.0), 'cat_l2': np.float64(0.018733242058042346), 'cat_smooth': np.float64(0.04376854914542821), 'max_cat_to_onehot': np.float64(68.0), 'lambda_l1': np.float64(0.001879955990420297), 'lambda_l2': np.float64(0.015437871083918458)}
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# self.fit_params[0]={'early_stopping_rounds': 300, 'n_estimators': 10000, 'learning_rate': np.float64(0.041352101130434325), 'feature_fraction': 0.6564762876769985, 'bagging_fraction': 0.7457526872980321, 'bagging_freq': 1, 'num_leaves': np.float64(53.0), 'min_data_in_leaf': np.float64(1.0), 'extra_trees': np.True_, 'min_data_per_group': np.float64(74.0), 'cat_l2': np.float64(0.012342053490316982), 'cat_smooth': np.float64(0.29845483963199654), 'max_cat_to_onehot': np.float64(9.0), 'lambda_l1': np.float64(0.3490235318364772), 'lambda_l2': np.float64(0.6834761593413804)}
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# self.fit_params[0]={'early_stopping_rounds': 300, 'n_estimators': 10000, 'learning_rate': np.float64(0.02087501701444785), 'feature_fraction': 0.5665131514432239, 'bagging_fraction': 0.9773690897834174, 'bagging_freq': 1, 'num_leaves': np.float64(19.0), 'min_data_in_leaf': np.float64(1.0), 'extra_trees': np.False_, 'min_data_per_group': np.float64(4.0), 'cat_l2': np.float64(0.0255197944955539), 'cat_smooth': np.float64(2.2543029689308285), 'max_cat_to_onehot': np.float64(73.0), 'lambda_l1': np.float64(0.9284964978804047), 'lambda_l2': np.float64(0.024900139360401807)}
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# self.fit_params[0]={'early_stopping_rounds': 300, 'n_estimators': 10000, 'learning_rate': np.float64(0.01335629322239949), 'feature_fraction': 0.994261474248731, 'bagging_fraction': 0.721096626456108, 'bagging_freq': 1, 'num_leaves': np.float64(2.0), 'min_data_in_leaf': np.float64(7.0), 'extra_trees': np.False_, 'min_data_per_group': np.float64(46.0), 'cat_l2': np.float64(0.07963016394761814), 'cat_smooth': np.float64(2.9360803928950037), 'max_cat_to_onehot': np.float64(41.0), 'lambda_l1': np.float64(3.550107740058501e-05), 'lambda_l2': np.float64(0.02230658151444196)}
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# self.fit_params[0]={'early_stopping_rounds': 300, 'n_estimators': 10000, 'learning_rate': np.float64(0.006866935813354527), 'feature_fraction': 0.8458025432789085, 'bagging_fraction': 0.8349605882230711, 'bagging_freq': 1, 'num_leaves': np.float64(99.0), 'min_data_in_leaf': np.float64(26.0), 'extra_trees': np.False_, 'min_data_per_group': np.float64(2.0), 'cat_l2': np.float64(0.00797566258819963), 'cat_smooth': np.float64(0.2274548355231281), 'max_cat_to_onehot': np.float64(21.0), 'lambda_l1': np.float64(0.1832059447224212), 'lambda_l2': np.float64(0.006050067818291317)}
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# self.fit_params[0]={'early_stopping_rounds': 300, 'n_estimators': 10000, 'learning_rate': np.float64(0.013288600389876818), 'feature_fraction': 0.6670401255294324, 'bagging_fraction': 0.9279422911771615, 'bagging_freq': 1, 'num_leaves': np.float64(179.0), 'min_data_in_leaf': np.float64(19.0), 'extra_trees': np.True_, 'min_data_per_group': np.float64(8.0), 'cat_l2': np.float64(0.006092703009357725), 'cat_smooth': np.float64(0.02588530576101597), 'max_cat_to_onehot': np.float64(73.0), 'lambda_l1': np.float64(0.31832743723222007), 'lambda_l2': np.float64(0.10423730901758822)}
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# self.fit_params[0]={'early_stopping_rounds': 300, 'n_estimators': 10000, 'learning_rate': np.float64(0.013922235684417198), 'feature_fraction': 0.7730115280351371, 'bagging_fraction': 0.8520203991022758, 'bagging_freq': 1, 'num_leaves': np.float64(19.0), 'min_data_in_leaf': np.float64(44.0), 'extra_trees': np.True_, 'min_data_per_group': np.float64(2.0), 'cat_l2': np.float64(0.23372869222485154), 'cat_smooth': np.float64(0.002952066453797857), 'max_cat_to_onehot': np.float64(45.0), 'lambda_l1': np.float64(0.15763199615568496), 'lambda_l2': np.float64(0.002671066723837902)}
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# self.fit_params[0]={'early_stopping_rounds': 300, 'n_estimators': 10000, 'learning_rate': np.float64(0.03661733203737489), 'feature_fraction': 0.5267290071553093, 'bagging_fraction': 0.7049935299391705, 'bagging_freq': 1, 'num_leaves': np.float64(31.0), 'min_data_in_leaf': np.float64(2.0), 'extra_trees': np.False_, 'min_data_per_group': np.float64(2.0), 'cat_l2': np.float64(1.8854326926989844), 'cat_smooth': np.float64(4.334730196836951), 'max_cat_to_onehot': np.float64(9.0), 'lambda_l1': np.float64(0.0003195771825462752), 'lambda_l2': np.float64(0.4868335842477151)}
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# self.fit_params[0]={'early_stopping_rounds': 300, 'n_estimators': 10000, 'learning_rate': np.float64(0.05860890996798138), 'feature_fraction': 0.7443645047118187, 'bagging_fraction': 0.8563366473385119, 'bagging_freq': 1, 'num_leaves': np.float64(56.0), 'min_data_in_leaf': np.float64(52.0), 'extra_trees': np.True_, 'min_data_per_group': np.float64(42.0), 'cat_l2': np.float64(0.008205073650208757), 'cat_smooth': np.float64(0.00345514141418617), 'max_cat_to_onehot': np.float64(42.0), 'lambda_l1': np.float64(0.0011799977797216032), 'lambda_l2': np.float64(5.768453889823086e-05)}
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# self.fit_params[0]={'early_stopping_rounds': 300, 'n_estimators': 10000, 'learning_rate': np.float64(0.016323856764925093), 'feature_fraction': 0.7408353551225044, 'bagging_fraction': 0.9130798710883015, 'bagging_freq': 1, 'num_leaves': np.float64(81.0), 'min_data_in_leaf': np.float64(16.0), 'extra_trees': np.True_, 'min_data_per_group': np.float64(15.0), 'cat_l2': np.float64(0.16610211501245428), 'cat_smooth': np.float64(0.26342314799099137), 'max_cat_to_onehot': np.float64(14.0), 'lambda_l1': np.float64(0.0017964319649538987), 'lambda_l2': np.float64(1.9612270315548843e-05)}
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# self.fit_params[0]={'early_stopping_rounds': 300, 'n_estimators': 10000, 'learning_rate': np.float64(0.07413620558567177), 'feature_fraction': 0.7113352409958212, 'bagging_fraction': 0.7316395255309938, 'bagging_freq': 1, 'num_leaves': np.float64(28.0), 'min_data_in_leaf': np.float64(5.0), 'extra_trees': np.True_, 'min_data_per_group': np.float64(51.0), 'cat_l2': np.float64(1.7078716436534132), 'cat_smooth': np.float64(0.11257372692624273), 'max_cat_to_onehot': np.float64(13.0), 'lambda_l1': np.float64(1.8793449825551026e-05), 'lambda_l2': np.float64(1.1060269113523714e-05)}
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# self.fit_params[0]={'early_stopping_rounds': 300, 'n_estimators': 10000, 'learning_rate': np.float64(0.016798741586722035), 'feature_fraction': 0.8973368321087829, 'bagging_fraction': 0.7920725970593108, 'bagging_freq': 1, 'num_leaves': np.float64(3.0), 'min_data_in_leaf': np.float64(43.0), 'extra_trees': np.True_, 'min_data_per_group': np.float64(9.0), 'cat_l2': np.float64(0.12715916528968454), 'cat_smooth': np.float64(0.0013712057893917984), 'max_cat_to_onehot': np.float64(58.0), 'lambda_l1': np.float64(0.0033174510320972232), 'lambda_l2': np.float64(0.0011368193752684704)}
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# self.fit_params[0]={'early_stopping_rounds': 300, 'n_estimators': 10000, 'learning_rate': np.float64(0.03358235545361272), 'feature_fraction': 0.4767761467604271, 'bagging_fraction': 0.9799679847437025, 'bagging_freq': 1, 'num_leaves': np.float64(2.0), 'min_data_in_leaf': np.float64(12.0), 'extra_trees': np.True_, 'min_data_per_group': np.float64(2.0), 'cat_l2': np.float64(0.028162297004321317), 'cat_smooth': np.float64(81.51027152584469), 'max_cat_to_onehot': np.float64(16.0), 'lambda_l1': np.float64(0.02376459564930294), 'lambda_l2': np.float64(3.981738591958382e-05)}
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# self.fit_params[0]={'early_stopping_rounds': 300, 'n_estimators': 10000, 'learning_rate': np.float64(0.059586850375519654), 'feature_fraction': 0.7358119420305784, 'bagging_fraction': 0.7846851675110327, 'bagging_freq': 1, 'num_leaves': np.float64(11.0), 'min_data_in_leaf': np.float64(1.0), 'extra_trees': np.True_, 'min_data_per_group': np.float64(19.0), 'cat_l2': np.float64(0.029742061333948577), 'cat_smooth': np.float64(25.845960104965133), 'max_cat_to_onehot': np.float64(23.0), 'lambda_l1': np.float64(1.9933947023508286e-05), 'lambda_l2': np.float64(0.147092937416951)}
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# self.fit_params[0]={'early_stopping_rounds': 300, 'n_estimators': 10000, 'learning_rate': np.float64(0.011031878422085292), 'feature_fraction': 0.52021348505408, 'bagging_fraction': 0.9666697957992103, 'bagging_freq': 1, 'num_leaves': np.float64(2.0), 'min_data_in_leaf': np.float64(1.0), 'extra_trees': np.False_, 'min_data_per_group': np.float64(33.0), 'cat_l2': np.float64(0.02073040907634547), 'cat_smooth': np.float64(17.59852357333939), 'max_cat_to_onehot': np.float64(81.0), 'lambda_l1': np.float64(0.0006753587776648031), 'lambda_l2': np.float64(0.00043779405043291883)}
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# self.fit_params[0]={'early_stopping_rounds': 300, 'n_estimators': 10000, 'learning_rate': np.float64(0.01077295064419035), 'feature_fraction': 0.6336440383440409, 'bagging_fraction': 0.8453315109545394, 'bagging_freq': 1, 'num_leaves': np.float64(95.0), 'min_data_in_leaf': np.float64(1.0), 'extra_trees': np.True_, 'min_data_per_group': np.float64(3.0), 'cat_l2': np.float64(0.10662620020986871), 'cat_smooth': np.float64(0.010557465402087445), 'max_cat_to_onehot': np.float64(34.0), 'lambda_l1': np.float64(0.06437572501443568), 'lambda_l2': np.float64(0.1777044313108673)}
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# self.fit_params[0]={'early_stopping_rounds': 300, 'n_estimators': 10000, 'learning_rate': np.float64(0.012334039626546747), 'feature_fraction': 0.8550713841006152, 'bagging_fraction': 0.9681202856069667, 'bagging_freq': 1, 'num_leaves': np.float64(53.0), 'min_data_in_leaf': np.float64(1.0), 'extra_trees': np.False_, 'min_data_per_group': np.float64(47.0), 'cat_l2': np.float64(0.01388022537593666), 'cat_smooth': np.float64(0.04985924071532254), 'max_cat_to_onehot': np.float64(93.0), 'lambda_l1': np.float64(0.012150003368098681), 'lambda_l2': np.float64(0.0007825910803047498)}
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# self.fit_params[0]={'early_stopping_rounds': 300, 'n_estimators': 10000, 'learning_rate': np.float64(0.015542556480757263), 'feature_fraction': 0.6923186163081185, 'bagging_fraction': 0.8076886426164418, 'bagging_freq': 1, 'num_leaves': np.float64(8.0), 'min_data_in_leaf': np.float64(15.0), 'extra_trees': np.True_, 'min_data_per_group': np.float64(4.0), 'cat_l2': np.float64(0.007363445476332797), 'cat_smooth': np.float64(0.11546009363869111), 'max_cat_to_onehot': np.float64(45.0), 'lambda_l1': np.float64(0.0002800571868430534), 'lambda_l2': np.float64(0.00931254229854953)}
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# self.fit_params[0]={'early_stopping_rounds': 300, 'n_estimators': 10000, 'learning_rate': np.float64(0.006559857835964499), 'feature_fraction': 0.933772301561735, 'bagging_fraction': 0.8159493345953682, 'bagging_freq': 1, 'num_leaves': np.float64(102.0), 'min_data_in_leaf': np.float64(9.0), 'extra_trees': np.False_, 'min_data_per_group': np.float64(4.0), 'cat_l2': np.float64(0.036712491489860444), 'cat_smooth': np.float64(1.4431792618094246), 'max_cat_to_onehot': np.float64(46.0), 'lambda_l1': np.float64(3.3834807376931704e-05), 'lambda_l2': np.float64(0.00830407098533813)}
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# self.fit_params[0]={'early_stopping_rounds': 300, 'n_estimators': 10000, 'learning_rate': np.float64(0.07165626232798146), 'feature_fraction': 0.6012961378828746, 'bagging_fraction': 0.7548080390403133, 'bagging_freq': 1, 'num_leaves': np.float64(16.0), 'min_data_in_leaf': np.float64(14.0), 'extra_trees': np.True_, 'min_data_per_group': np.float64(26.0), 'cat_l2': np.float64(0.08012191767787206), 'cat_smooth': np.float64(0.05412872240615383), 'max_cat_to_onehot': np.float64(21.0), 'lambda_l1': np.float64(0.35959313727663483), 'lambda_l2': np.float64(0.011980047399536512)}
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# self.fit_params[0]={'early_stopping_rounds': 300, 'n_estimators': 10000, 'learning_rate': np.float64(0.042263295842527915), 'feature_fraction': 0.42351780137814843, 'bagging_fraction': 0.9992327238481415, 'bagging_freq': 1, 'num_leaves': np.float64(2.0), 'min_data_in_leaf': np.float64(1.0), 'extra_trees': np.True_, 'min_data_per_group': np.float64(68.0), 'cat_l2': np.float64(0.05969092625799465), 'cat_smooth': np.float64(0.1403061250061059), 'max_cat_to_onehot': np.float64(9.0), 'lambda_l1': np.float64(0.02310097716020392), 'lambda_l2': np.float64(3.840522797829543e-05)}
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# self.fit_params[0]={'early_stopping_rounds': 300, 'n_estimators': 10000, 'learning_rate': np.float64(0.08724768057758521), 'feature_fraction': 0.9800878811727776, 'bagging_fraction': 0.8511796074248259, 'bagging_freq': 1, 'num_leaves': np.float64(122.0), 'min_data_in_leaf': np.float64(9.0), 'extra_trees': np.False_, 'min_data_per_group': np.float64(6.0), 'cat_l2': np.float64(0.006349043965547177), 'cat_smooth': np.float64(0.2768384665745461), 'max_cat_to_onehot': np.float64(32.0), 'lambda_l1': np.float64(1.951959207140209e-05), 'lambda_l2': np.float64(1.4587662099452803e-05)}
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# self.fit_params[0]={'early_stopping_rounds': 300, 'n_estimators': 10000, 'learning_rate': np.float64(0.005851101060287882), 'feature_fraction': 0.5634765592734722, 'bagging_fraction': 0.940097217206979, 'bagging_freq': 1, 'num_leaves': np.float64(119.0), 'min_data_in_leaf': np.float64(1.0), 'extra_trees': np.False_, 'min_data_per_group': np.float64(5.0), 'cat_l2': np.float64(0.02000993035618805), 'cat_smooth': np.float64(0.6125801541150605), 'max_cat_to_onehot': np.float64(52.0), 'lambda_l1': np.float64(0.00155407922923545), 'lambda_l2': np.float64(0.0001767721899290469)}
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# self.fit_params[0]={'early_stopping_rounds': 300, 'n_estimators': 10000, 'learning_rate': np.float64(0.014842646986112347), 'feature_fraction': 0.5432813164423985, 'bagging_fraction': 0.8126692228109921, 'bagging_freq': 1, 'num_leaves': np.float64(131.0), 'min_data_in_leaf': np.float64(49.0), 'extra_trees': np.True_, 'min_data_per_group': np.float64(42.0), 'cat_l2': np.float64(0.010729773952585977), 'cat_smooth': np.float64(0.42257602571975944), 'max_cat_to_onehot': np.float64(28.0), 'lambda_l1': np.float64(0.05557464358522857), 'lambda_l2': np.float64(0.0009701264486002928)}
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# params["n_estimators"]=10000
# self.fit_params[0]={'n_estimators': 10000, 'early_stopping_rounds': 300, 'eta': np.float64(0.006259412766996183), 'max_depth': np.int64(5), 'min_child_weight': np.float64(0.0035031278426985784), 'subsample': 0.6506531836974154, 'colsample_bylevel': 0.7590947692283092, 'colsample_bynode': 0.6751704256950675, 'reg_alpha': np.float64(3.9963299181867415), 'reg_lambda': np.float64(0.0009978311366705041), 'grow_policy': np.str_('depthwise'), 'max_cat_to_onehot': 19, 'max_leaves': 10}
# self.fit_params[0]={'n_estimators': 10000, 'early_stopping_rounds': 300, 'eta': np.float64(0.011183442040921405), 'max_depth': np.int64(5), 'min_child_weight': np.float64(0.00364883032062861), 'subsample': 0.8761900618011338, 'colsample_bylevel': 0.904749268117618, 'colsample_bynode': 0.6819615625194863, 'reg_alpha': np.float64(0.04150465111133429), 'reg_lambda': np.float64(2.429602722965842), 'grow_policy': np.str_('lossguide'), 'max_cat_to_onehot': 16, 'max_leaves': 208}
# self.fit_params[0]={'n_estimators': 10000, 'early_stopping_rounds': 300, 'eta': np.float64(0.08258942937466404), 'max_depth': np.int64(9), 'min_child_weight': np.float64(0.002099417902563572), 'subsample': 0.9991025422568683, 'colsample_bylevel': 0.7587849739197197, 'colsample_bynode': 0.7477983836481401, 'reg_alpha': np.float64(3.551161526241213), 'reg_lambda': np.float64(0.0648859363871089), 'grow_policy': np.str_('depthwise'), 'max_cat_to_onehot': 73, 'max_leaves': 575}
# self.fit_params[0]={'n_estimators': 10000, 'early_stopping_rounds': 300, 'eta': np.float64(0.02447971676840772), 'max_depth': np.int64(8), 'min_child_weight': np.float64(0.008603069968511515), 'subsample': 0.8925553728669201, 'colsample_bylevel': 0.8854544969111947, 'colsample_bynode': 0.8719146193988412, 'reg_alpha': np.float64(0.0008443646158106684), 'reg_lambda': np.float64(0.678079272279293), 'grow_policy': np.str_('depthwise'), 'max_cat_to_onehot': 9, 'max_leaves': 81}
# self.fit_params[0]={'n_estimators': 10000, 'early_stopping_rounds': 300, 'eta': np.float64(0.05844266290629866), 'max_depth': np.int64(8), 'min_child_weight': np.float64(0.17152733296853798), 'subsample': 0.7462494664407884, 'colsample_bylevel': 0.6037953732021488, 'colsample_bynode': 0.850323550015372, 'reg_alpha': np.float64(0.005250168808290781), 'reg_lambda': np.float64(0.024274349712148317), 'grow_policy': np.str_('lossguide'), 'max_cat_to_onehot': 50, 'max_leaves': 267}
# self.fit_params[0]={'n_estimators': 10000, 'early_stopping_rounds': 300, 'eta': np.float64(0.06276648589619285), 'max_depth': np.int64(9), 'min_child_weight': np.float64(0.1509923643152388), 'subsample': 0.7484231030447371, 'colsample_bylevel': 0.6403684055267247, 'colsample_bynode': 0.9902269863542196, 'reg_alpha': np.float64(3.8959276243643015), 'reg_lambda': np.float64(0.002148788267835373), 'grow_policy': np.str_('depthwise'), 'max_cat_to_onehot': 35, 'max_leaves': 13}
# self.fit_params[0]={'n_estimators': 10000, 'early_stopping_rounds': 300, 'eta': np.float64(0.03536730859732128), 'max_depth': np.int64(7), 'min_child_weight': np.float64(0.21028658527122593), 'subsample': 0.7773854304189131, 'colsample_bylevel': 0.8831522543016594, 'colsample_bynode': 0.9261382627511878, 'reg_alpha': np.float64(0.0718735805600673), 'reg_lambda': np.float64(1.7894042152509455), 'grow_policy': np.str_('depthwise'), 'max_cat_to_onehot': 98, 'max_leaves': 174}
# self.fit_params[0]={'n_estimators': 10000, 'early_stopping_rounds': 300, 'eta': np.float64(0.016327394487041617), 'max_depth': np.int64(4), 'min_child_weight': np.float64(0.7361060640985897), 'subsample': 0.9269782798996402, 'colsample_bylevel': 0.9959042754579317, 'colsample_bynode': 0.9820123325178803, 'reg_alpha': np.float64(0.07702074613383181), 'reg_lambda': np.float64(0.014633932748759314), 'grow_policy': np.str_('lossguide'), 'max_cat_to_onehot': 97, 'max_leaves': 100}
# self.fit_params[0]={'n_estimators': 10000, 'early_stopping_rounds': 300, 'eta': np.float64(0.006975973059218868), 'max_depth': np.int64(7), 'min_child_weight': np.float64(0.6196937642582667), 'subsample': 0.6341391667219197, 'colsample_bylevel': 0.6569830169496707, 'colsample_bynode': 0.6500559279874366, 'reg_alpha': np.float64(0.016841470347149785), 'reg_lambda': np.float64(0.048542806431560975), 'grow_policy': np.str_('lossguide'), 'max_cat_to_onehot': 20, 'max_leaves': 269}
# self.fit_params[0]={'n_estimators': 10000, 'early_stopping_rounds': 300, 'eta': np.float64(0.05980438281797063), 'max_depth': np.int64(8), 'min_child_weight': np.float64(1.2423181507837235), 'subsample': 0.973211664095382, 'colsample_bylevel': 0.8009034279121302, 'colsample_bynode': 0.9624740400857411, 'reg_alpha': np.float64(4.496213101219655), 'reg_lambda': np.float64(0.00020476307701248494), 'grow_policy': np.str_('depthwise'), 'max_cat_to_onehot': 28, 'max_leaves': 862}
# self.fit_params[0]={'n_estimators': 10000, 'early_stopping_rounds': 300, 'eta': np.float64(0.05903888061344897), 'max_depth': np.int64(8), 'min_child_weight': np.float64(0.0787764236727461), 'subsample': 0.8448269031898947, 'colsample_bylevel': 0.9172765921504362, 'colsample_bynode': 0.7544808510262865, 'reg_alpha': np.float64(0.031207442395405873), 'reg_lambda': np.float64(0.33188610210885605), 'grow_policy': np.str_('lossguide'), 'max_cat_to_onehot': 90, 'max_leaves': 144}
# self.fit_params[0]={'n_estimators': 10000, 'early_stopping_rounds': 300, 'eta': np.float64(0.019950634706857883), 'max_depth': np.int64(9), 'min_child_weight': np.float64(3.0579054185200034), 'subsample': 0.8599896589004055, 'colsample_bylevel': 0.7895205737035373, 'colsample_bynode': 0.6070884456187534, 'reg_alpha': np.float64(0.19116618877267505), 'reg_lambda': np.float64(0.04562853040474844), 'grow_policy': np.str_('lossguide'), 'max_cat_to_onehot': 18, 'max_leaves': 16}
# self.fit_params[0]={'n_estimators': 10000, 'early_stopping_rounds': 300, 'eta': np.float64(0.035815058916289326), 'max_depth': np.int64(9), 'min_child_weight': np.float64(0.0021140385524826685), 'subsample': 0.9450180645401546, 'colsample_bylevel': 0.7340624206940606, 'colsample_bynode': 0.6882971607605042, 'reg_alpha': np.float64(0.00014644056837088637), 'reg_lambda': np.float64(0.007563698253934776), 'grow_policy': np.str_('depthwise'), 'max_cat_to_onehot': 10, 'max_leaves': 15}
# self.fit_params[0]={'n_estimators': 10000, 'early_stopping_rounds': 300, 'eta': np.float64(0.005805302432661942), 'max_depth': np.int64(5), 'min_child_weight': np.float64(0.39377372589438575), 'subsample': 0.7134833948174248, 'colsample_bylevel': 0.7289047348113815, 'colsample_bynode': 0.8523854064832985, 'reg_alpha': np.float64(0.0003666842376414939), 'reg_lambda': np.float64(2.281237251988868), 'grow_policy': np.str_('depthwise'), 'max_cat_to_onehot': 62, 'max_leaves': 12}
# self.fit_params[0]={'n_estimators': 10000, 'early_stopping_rounds': 300, 'eta': np.float64(0.03599092462960644), 'max_depth': np.int64(5), 'min_child_weight': np.float64(1.3126743774475718), 'subsample': 0.7262774451801263, 'colsample_bylevel': 0.6808271982315353, 'colsample_bynode': 0.8697037289256979, 'reg_alpha': np.float64(0.016788070079386812), 'reg_lambda': np.float64(0.0008583691380639662), 'grow_policy': np.str_('lossguide'), 'max_cat_to_onehot': 51, 'max_leaves': 24}
# self.fit_params[0]={'n_estimators': 10000, 'early_stopping_rounds': 300, 'eta': np.float64(0.04369861607306223), 'max_depth': np.int64(5), 'min_child_weight': np.float64(1.24415336423496), 'subsample': 0.9182474437494359, 'colsample_bylevel': 0.8842383383417768, 'colsample_bynode': 0.9808627623468621, 'reg_alpha': np.float64(0.011259488788389548), 'reg_lambda': np.float64(0.5749355536109657), 'grow_policy': np.str_('lossguide'), 'max_cat_to_onehot': 37, 'max_leaves': 412}
# self.fit_params[0]={'n_estimators': 10000, 'early_stopping_rounds': 300, 'eta': np.float64(0.02658516197807651), 'max_depth': np.int64(6), 'min_child_weight': np.float64(0.006565342919396832), 'subsample': 0.6250319198067926, 'colsample_bylevel': 0.6761382350053355, 'colsample_bynode': 0.8198119447287615, 'reg_alpha': np.float64(0.10146365638612263), 'reg_lambda': np.float64(0.04378552882457734), 'grow_policy': np.str_('lossguide'), 'max_cat_to_onehot': 78, 'max_leaves': 313}
# self.fit_params[0]={'n_estimators': 10000, 'early_stopping_rounds': 300, 'eta': np.float64(0.019517855195247798), 'max_depth': np.int64(7), 'min_child_weight': np.float64(0.08544846656030611), 'subsample': 0.7526130340758951, 'colsample_bylevel': 0.6124874490435906, 'colsample_bynode': 0.6775545512636485, 'reg_alpha': np.float64(0.005093929296873104), 'reg_lambda': np.float64(0.8928773985244238), 'grow_policy': np.str_('lossguide'), 'max_cat_to_onehot': 27, 'max_leaves': 64}
# self.fit_params[0]={'n_estimators': 10000, 'early_stopping_rounds': 300, 'eta': np.float64(0.03569715939619957), 'max_depth': np.int64(6), 'min_child_weight': np.float64(0.868259277840318), 'subsample': 0.9979111510710738, 'colsample_bylevel': 0.9146338857384831, 'colsample_bynode': 0.7759060677813086, 'reg_alpha': np.float64(0.045060636930855), 'reg_lambda': np.float64(0.5381793138554897), 'grow_policy': np.str_('depthwise'), 'max_cat_to_onehot': 34, 'max_leaves': 17}
# self.fit_params[0]={'n_estimators': 10000, 'early_stopping_rounds': 300, 'eta': np.float64(0.038786373652236084), 'max_depth': np.int64(4), 'min_child_weight': np.float64(0.0010219517880339366), 'subsample': 0.8695671358127357, 'colsample_bylevel': 0.6410792924355315, 'colsample_bynode': 0.6520672583008386, 'reg_alpha': np.float64(4.651889430759315), 'reg_lambda': np.float64(0.23199199288904887), 'grow_policy': np.str_('depthwise'), 'max_cat_to_onehot': 21, 'max_leaves': 40}
# self.fit_params[0]={'n_estimators': 10000, 'early_stopping_rounds': 300, 'eta': np.float64(0.015049060452015596), 'max_depth': np.int64(10), 'min_child_weight': np.float64(0.04150927004584298), 'subsample': 0.9218707242170331, 'colsample_bylevel': 0.9824610462460854, 'colsample_bynode': 0.6453991043873877, 'reg_alpha': np.float64(0.013435990053814576), 'reg_lambda': np.float64(0.018589187351472036), 'grow_policy': np.str_('lossguide'), 'max_cat_to_onehot': 65, 'max_leaves': 28}
# self.fit_params[0]={'n_estimators': 10000, 'early_stopping_rounds': 300, 'eta': np.float64(0.07506107395670433), 'max_depth': np.int64(10), 'min_child_weight': np.float64(0.0022841664579918877), 'subsample': 0.9184320638178896, 'colsample_bylevel': 0.7744450121067024, 'colsample_bynode': 0.6569568688622622, 'reg_alpha': np.float64(0.004037102502629276), 'reg_lambda': np.float64(0.002432260159836498), 'grow_policy': np.str_('depthwise'), 'max_cat_to_onehot': 13, 'max_leaves': 309}
# self.fit_params[0]={'n_estimators': 10000, 'early_stopping_rounds': 300, 'eta': np.float64(0.008537401868569093), 'max_depth': np.int64(5), 'min_child_weight': np.float64(0.03555416463639583), 'subsample': 0.731876449708524, 'colsample_bylevel': 0.9105258606601052, 'colsample_bynode': 0.8393004527315918, 'reg_alpha': np.float64(0.013453623254629173), 'reg_lambda': np.float64(0.005991031474666334), 'grow_policy': np.str_('depthwise'), 'max_cat_to_onehot': 58, 'max_leaves': 364}
# self.fit_params[0]={'n_estimators': 10000, 'early_stopping_rounds': 300, 'eta': np.float64(0.018334230225147206), 'max_depth': np.int64(7), 'min_child_weight': np.float64(1.8119503702753992), 'subsample': 0.8509258547324775, 'colsample_bylevel': 0.7673483076620635, 'colsample_bynode': 0.9301768729575395, 'reg_alpha': np.float64(0.6461467330112836), 'reg_lambda': np.float64(0.07422811879135949), 'grow_policy': np.str_('depthwise'), 'max_cat_to_onehot': 36, 'max_leaves': 504}
# ...
# self.fit_params[0]={'n_estimators': 10000, 'early_stopping_rounds': 300, 'eta': np.float64(0.020131455654840934), 'max_depth': np.int64(9), 'min_child_weight': np.float64(0.002301122240715914), 'subsample': 0.7641872929885576, 'colsample_bylevel': 0.8510279981698559, 'colsample_bynode': 0.9648308990871313, 'reg_alpha': np.float64(0.002500115733221967), 'reg_lambda': np.float64(0.027766392714283824), 'grow_policy': np.str_('lossguide'), 'max_cat_to_onehot': 10, 'max_leaves': 362}
# self.fit_params[0]={'n_estimators': 10000, 'early_stopping_rounds': 300, 'learning_rate': np.float64(0.009329162239751363), 'bootstrap_type': 'Bernoulli', 'subsample': 0.9811766812444176, 'grow_policy': np.str_('SymmetricTree'), 'max_depth': np.int64(4), 'colsample_bylevel': 0.8954423389817875, 'l2_leaf_reg': np.float64(0.050175443353863876), 'leaf_estimation_iterations': np.float64(1.0), 'one_hot_max_size': np.float64(8.0), 'model_size_reg': np.float64(1.2820173957946976), 'max_ctr_complexity': np.int64(3), 'boosting_type': 'Plain', 'max_bin': 254}
# self.fit_params[0]={'n_estimators': 10000, 'early_stopping_rounds': 300, 'learning_rate': np.float64(0.007052766285036304), 'bootstrap_type': 'Bernoulli', 'subsample': 0.7815378913044528, 'grow_policy': np.str_('Depthwise'), 'max_depth': np.int64(8), 'colsample_bylevel': 0.971673752943585, 'l2_leaf_reg': np.float64(0.0009331750694534258), 'leaf_estimation_iterations': np.float64(14.0), 'one_hot_max_size': np.float64(37.0), 'model_size_reg': np.float64(0.2090311349448443), 'max_ctr_complexity': np.int64(3), 'boosting_type': 'Plain', 'max_bin': 254}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 ptk_cv = cross_validate(pipe, X, y, scoring='neg_mean_squared_error', cv=5, params={'model__cat_col_names': ['categorical__genre_metacritic', 'categorical__developer_metacritic']}, error_score='raise')
#
# File ~\DataspellProjects\derks-backlog\.venv\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~\DataspellProjects\derks-backlog\.venv\Lib\site-packages\sklearn\model_selection\_validation.py:399, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, params, pre_dispatch, return_train_score, return_estimator, return_indices, error_score)
#     396 # We clone the estimator to make sure that all the folds are
#     397 # independent, and that it is pickle-able.
#     398 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 399 results = parallel(
#     400     delayed(_fit_and_score)(
#     401         clone(estimator),
#     402         X,
#     403         y,
#     404         scorer=scorers,
#     405         train=train,
#     406         test=test,
#     407         verbose=verbose,
#     408         parameters=None,
#     409         fit_params=routed_params.estimator.fit,
#     410         score_params=routed_params.scorer.score,
#     411         return_train_score=return_train_score,
#     412         return_times=True,
#     413         return_estimator=return_estimator,
#     414         error_score=error_score,
#     415     )
#     416     for train, test in indices
#     417 )
#     419 _warn_or_raise_about_fit_failures(results, error_score)
#     421 # For callable scoring, the return type is only know after calling. If the
#     422 # return type is a dictionary, the error scores can now be inserted with
#     423 # the correct key.
#
# File ~\DataspellProjects\derks-backlog\.venv\Lib\site-packages\sklearn\utils\parallel.py:82, in Parallel.__call__(self, iterable)
#      73 warning_filters = warnings.filters
#      74 iterable_with_config_and_warning_filters = (
#      75     (
#      76         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)     80     for delayed_func, args, kwargs in iterable
#      81 )
# ---> 82 return super().__call__(iterable_with_config_and_warning_filters)
#
# File ~\DataspellProjects\derks-backlog\.venv\Lib\site-packages\joblib\parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File ~\DataspellProjects\derks-backlog\.venv\Lib\site-packages\joblib\parallel.py:1914, in Parallel._get_sequential_output(self, iterable)
#    1912 self.n_dispatched_batches += 1
#    1913 self.n_dispatched_tasks += 1
# -> 1914 res = func(*args, **kwargs)
#    1915 self.n_completed_tasks += 1
#    1916 self.print_progress()
#
# File ~\DataspellProjects\derks-backlog\.venv\Lib\site-packages\sklearn\utils\parallel.py:147, in _FuncWrapper.__call__(self, *args, **kwargs)
#     145 with config_context(**config), warnings.catch_warnings():
#     146     warnings.filters = warning_filters
# --> 147     return self.function(*args, **kwargs)
#
# File ~\DataspellProjects\derks-backlog\.venv\Lib\site-packages\sklearn\model_selection\_validation.py:859, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, score_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     857         estimator.fit(X_train, **fit_params)
#     858     else:
# --> 859         estimator.fit(X_train, y_train, **fit_params)
#     861 except Exception:
#     862     # Note fit time as time until error
#     863     fit_time = time.time() - start_time
#
# File ~\DataspellProjects\derks-backlog\.venv\Lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~\DataspellProjects\derks-backlog\.venv\Lib\site-packages\sklearn\pipeline.py:663, in Pipeline.fit(self, X, y, **params)
#     657     if self._final_estimator != "passthrough":
#     658         last_step_params = self._get_metadata_for_step(
#     659             step_idx=len(self) - 1,
#     660             step_params=routed_params[self.steps[-1][0]],
#     661             all_params=params,
#     662         )
# --> 663         self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#     665 return self
#
# File ~\DataspellProjects\derks-backlog\.venv\Lib\site-packages\pytabkit\models\sklearn\sklearn_base.py:407, in AlgInterfaceEstimator.fit(self, X, y, X_val, y_val, val_idxs, cat_indicator, cat_col_names, time_to_fit_in_seconds)
#     403 logger = StdoutLogger(verbosity_level=params.get('verbosity', 0))
#     405 interface_resources = InterfaceResources(n_threads=n_threads, gpu_devices=gpu_devices,
#     406                                          time_in_seconds=time_to_fit_in_seconds)
# --> 407 self.cv_alg_interface_.fit(ds=ds, idxs_list=idxs_list, interface_resources=interface_resources,
#     408                            logger=logger, tmp_folders=tmp_folders, name=self.__class__.__name__)
#     410 # todo: put alg_interface on the CPU after fit() (for saving)? How to do it?
#     411
#     412 # todo: currently, there is only one alg_interface which may fit in parallel (for the NNs),
#     413 #  but we could add an option to make them fit sequentially for RAM reasons or so
#     414 #  (maybe this is best done via a MultiSplitWrapper or so)
#     416 if n_refit > 0:
#
# File ~\DataspellProjects\derks-backlog\.venv\Lib\site-packages\pytabkit\models\alg_interfaces\ensemble_interfaces.py:75, in CaruanaEnsembleAlgInterface.fit(self, ds, idxs_list, interface_resources, logger, tmp_folders, name)
#      73         else:
#      74             sub_idxs_list = idxs_list
# ---> 75         alg_interface.fit(ds, sub_idxs_list, interface_resources, logger, sub_tmp_folders,
#      76                           name + f'sub-alg-{alg_idx}')
#      77         sub_fit_params.append(alg_interface.get_fit_params()[0])
#      79 if self.fit_params is not None:
#      80     # this is the refit stage, there is no validation data set to determine the weights on,
#      81     # instead the weights are already in fit_params
#
# File ~\DataspellProjects\derks-backlog\.venv\Lib\site-packages\pytabkit\models\alg_interfaces\alg_interfaces.py:492, in RandomParamsAlgInterface.fit(self, ds, idxs_list, interface_resources, logger, tmp_folders, name)
#     489 self.alg_interface = self._create_sub_interface(ds, idxs_list[0].split_seed, n_train=idxs_list[0].n_train,
#     490                                                 n_tv_splits=n_tv_splits)
#     491 print(f'{self.fit_params[0]=}')
# --> 492 self.alg_interface.fit(ds, idxs_list, interface_resources, logger, tmp_folders, name)
#     493 self.fit_params[0]['sub_fit_params'] = self.alg_interface.fit_params[0]
#
# File ~\DataspellProjects\derks-backlog\.venv\Lib\site-packages\pytabkit\models\alg_interfaces\sub_split_interfaces.py:81, in SingleSplitWrapperAlgInterface.fit(self, ds, idxs_list, interface_resources, logger, tmp_folders, name)
#      75 sub_tmp_folder = tmp_folder / f'sub_split_{i}' if tmp_folder is not None else None
#      76 # don't set fit_params here
#      77 # because we might intentionally not want to set them if use_best_mean_iteration_for_refit==False
#      78 # see get_refit_interfaces()
#      79 # if self.fit_params is not None:
#      80 #     self.sub_split_interfaces[i].fit_params = self.fit_params
# ---> 81 hyper_results = self.sub_split_interfaces[i].fit(ds, sub_split_idxs, interface_resources, logger,
#      82                                                  [sub_tmp_folder], name=name)
#      83 hyper_results = hyper_results[0][0] if hyper_results is not None else []
#      84 hyper_results_list.append(hyper_results)
#
# File ~\DataspellProjects\derks-backlog\.venv\Lib\site-packages\pytabkit\models\alg_interfaces\sub_split_interfaces.py:328, in TreeBasedSubSplitInterface.fit(self, ds, idxs_list, interface_resources, logger, tmp_folders, name)
#     326 if len(gpu_ids) > 0 and self.config.get('allow_gpu', True):
#     327     params['device'] = f'cuda:{gpu_ids[0]}'  # this is for XGBoost 2.0 and CatBoost
# --> 328 self.model, val_errors = self._fit(train_ds, val_ds, params=params, seed=seed,
#     329                                    n_threads=interface_resources.n_threads,
#     330                                    val_metric_name=self.config.get('val_metric_name', None),
#     331                                    tmp_folder=tmp_folders[0])
#     332 if val_errors is None:
#     333     return None
#
# File ~\DataspellProjects\derks-backlog\.venv\Lib\site-packages\pytabkit\models\alg_interfaces\catboost_interfaces.py:256, in CatBoostSubSplitInterface._fit(self, train_ds, val_ds, params, seed, n_threads, val_metric_name, tmp_folder)
#     254 with warnings.catch_warnings():
#     255     warnings.filterwarnings('ignore', message='Can\'t optimize method "evaluate" because self argument is used')
# --> 256     bst.fit(self._convert_ds(train_ds), eval_set=None if val_ds is None else self._convert_ds(val_ds))
#     258 if val_ds is not None:
#     259     evals_result = bst.get_evals_result()
#
# File ~\DataspellProjects\derks-backlog\.venv\Lib\site-packages\catboost\core.py:2589, in CatBoost.fit(self, X, y, cat_features, text_features, embedding_features, pairs, graph, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    2452 def fit(self, X, y=None, cat_features=None, text_features=None, embedding_features=None, pairs=None, graph=None, sample_weight=None, group_id=None,
#    2453         group_weight=None, subgroup_id=None, pairs_weight=None, baseline=None, use_best_model=None,
#    2454         eval_set=None, verbose=None, logging_level=None, plot=False, plot_file=None, column_description=None,
#    2455         verbose_eval=None, metric_period=None, silent=None, early_stopping_rounds=None,
#    2456         save_snapshot=None, snapshot_file=None, snapshot_interval=None, init_model=None, callbacks=None,
#    2457         log_cout=None, log_cerr=None):
#    2458     """
#    2459     Fit the CatBoost model.
#    2460
#    (...)   2587     model : CatBoost
#    2588     """
# -> 2589     return self._fit(X, y, cat_features, text_features, embedding_features, pairs, graph, sample_weight, group_id, group_weight, subgroup_id,
#    2590                      pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file,
#    2591                      column_description, verbose_eval, metric_period, silent, early_stopping_rounds,
#    2592                      save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#
# File ~\DataspellProjects\derks-backlog\.venv\Lib\site-packages\catboost\core.py:2410, in CatBoost._fit(self, X, y, cat_features, text_features, embedding_features, pairs, graph, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    2407 allow_clear_pool = train_params["allow_clear_pool"]
#    2409 with plot_wrapper(plot, plot_file, 'Training plots', [_get_train_dir(self.get_params())]):
# -> 2410     self._train(
#    2411         train_pool,
#    2412         train_params["eval_sets"],
#    2413         params,
#    2414         allow_clear_pool,
#    2415         train_params["init_model"]
#    2416     )
#    2418 # Have property feature_importance possibly set
#    2419 loss = self._object._get_loss_function_name()
#
# File ~\DataspellProjects\derks-backlog\.venv\Lib\site-packages\catboost\core.py:1790, in _CatBoostBase._train(self, train_pool, test_pool, params, allow_clear_pool, init_model)
#    1789 def _train(self, train_pool, test_pool, params, allow_clear_pool, init_model):
# -> 1790     self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#    1791     self._set_trained_model_attributes()
#
# File _catboost.pyx:5023, in _catboost._CatBoost._train()
#
# File _catboost.pyx:5072, in _catboost._CatBoost._train()
#
# KeyboardInterrupt:

# %%
ptk_cv
# Out:
# {'fit_time': array([164.49928069, 171.4677515 , 173.02885723, 162.18768382,
#         166.05649424]),
#  'score_time': array([0.02450991, 0.02599907, 0.03000116, 0.03100276, 0.03651214]),
#  'test_score': array([-24110.61659285, -38046.71304304, -27556.09545123, -58761.20199099,
#         -57711.39999812])}
